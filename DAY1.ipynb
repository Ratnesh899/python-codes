# %% [markdown]
# <a href="https://colab.research.google.com/github/Ratnesh899/python-codes/blob/main/DAY1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
a=5
print(a)
# Out:
# 5

# %%
print("This is my first lab!")
# Out:
# This is my first lab!

# %%
a=4
print("The value of a is: ", a)
# Out:
# The value of a is:  4

# %%
name="Ratnesh"
age=19
print(name , age )
# Out:
# Ratnesh 19

# %%
name="Ratnesh"
age=19
print("%s is %d year old" %(name,age))
# Out:
# Ratnesh is 19 year old

# %%
name = "Ratnesh"
age = 19
print(f"Name: {name} , Age: {age}")
# Out:
# Name: Ratnesh , Age: 19

# %%
name = "Ratnesh"
age = 19
print("Name: {}, Age: {}".format(name, age))
# Out:
# Name: Ratnesh, Age: 19

# %%
age = 36
txt ="My name is john , and I am {}"
print (txt.format(age))
# Out:
# My name is john , and I am 36

# %%
quantity = 3
iteamo = 567
price = 49.96
myorder = "I want {} pieces of iteam {} for {} dollors."
print(myorder.format(quantity , iteamo , price  ))
# Out:
# I want 3 pieces of iteam 567 for 49.96 dollors.

# %%
quantity = 3
iteamo = 567
price = 49.96
myorder = "I want {2} pieces of iteam {1} for {0} dollors."
print(myorder.format(quantity , iteamo , price  ))
# Out:
# I want 49.96 pieces of iteam 567 for 3 dollors.

# %%
#HW# question 1
print("Question1!")
num1 = 4
num2 = 6
num3 = 3
average = (num1+num2+num3)/3
print(average)

# Question 2 #
print("Question2!")
sub1 = 60
sub2 = 30
sub3 = 40
sub4 = 50
sub5 = 60
total = sub1+sub2+sub3+sub4+sub5
print(total)
percentage = (total/500)*100
print(percentage)

#  Question 3 #
print("Question3!")
radius = float(input("Enter the number:"))
pi = 3.14
area = pi*radius*radius
print(area)

# Question 4 #
print("Question4!")
length = float(input("Enter the number:"))
width = float(input("Enter the number:"))
Area = length*width
print(area)

#Question 5 #
print("Question5!")
side = float(input("Enter the number:"))
Area = side*side
print(Area)

# Question 6 #
print("Question6!")
radius = float(input("Enter the number:"))
pi = 3.14
circumference = 2*pi*radius
print(circumference)

#  Question 7 #
print("Question7!")
a = float(input("Enter the number:"))
b = float(input("Enter the number:"))
c = float(input("Enter the number:"))
s = (a+b+c)/2
area = (s*(s-a)*(s-b)*(s-c))
print("Area of the triangle:" , area)

# Question 8 #
print("Question8!")
base = float(input("Enter the number:"))
Height = float(input("Enter the number:"))
area = (base*Height)/2
print("Area of Right angle Triangle:" , area)

# question 9 #
print("Question9!")
base1 = float(input("Enter the number:"))
base2 = float(input("Enter the number:"))
Height = float(input("Enter the number:"))
area = (base1 + base2)*Height/2
print("Area of Trapezium:" , area )
# Out:
# Question1!
# 4.333333333333333
# Question2!
# 240
# 48.0
# Question3!
# Enter the number:7
# 153.86
# Question4!
# Enter the number:7
# Enter the number:8
# 153.86
# Question5!
# Enter the number:6
# 36.0
# Question6!
# Enter the number:9
# 56.52
# Question7!
# Enter the number:6
# Enter the number:6
# Enter the number:8
# Area of the triangle: 320.0
# Question8!
# Enter the number:7
# Enter the number:6
# Area of Right angle Triangle: 21.0
# Question9!
# Enter the number:5
# Enter the number:4
# Enter the number:4
# Area of Trapezium: 18.0
