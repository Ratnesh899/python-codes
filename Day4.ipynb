# %% [markdown]
# <a href="https://colab.research.google.com/github/Ratnesh899/python-codes/blob/main/Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = {1,2,3,4}
print(s)
# Out:
# {1, 2, 3, 4}

# %%
# convert  upper case to lower case
s ="Ratnesh mishra"
print(s.lower())
print(s.upper())
# Out:
# ratnesh mishra
# RATNESH MISHRA

# %%
#Even or

# %%
# if else even odd condition
n = int(input("enter the number"))
if n%2==0:
    print("even number")
else:
    print("odd number")
# Out:
# enter the number8
# even number

# %%
#if else for vote elibilty
age = int(input("enter the age"))
if age>=18:
    print("you are eligible for vote")
else:
    print("you are not eligible for vote")
# Out:
# enter the age6
# you are not eligible for vote

# %%
# eif else condnditin to find which number greater
x = int(input("enter the number"))
y = int(input("enter the number"))
z = int(input("enter the number"))
if x>y and x>z:
    print("x is greater")
elif  y>x and y>z:
    print("y is greater")
else:
    print("z is greater")
# Out:
# enter the number8
# enter the number9
# enter the number10
# z is greater

# %%
a=int(input("enter a the number"))
# Out:
# enter the number0
#  is not a prime number

# %%
# if elif condition range
if(x>=0 and x<=100):
    print("it is the range of 0-100")
    elif()

# %%
# Make the calculator
a = int(input("enter the number"))
b = int(input("enter the number"))
s = a+b
print(s)
d = a-b
print(d)
m = a*b
print(m)
d = a/b
print(d)
# Out:
# enter the number5
# enter the number4
# 9
# 1
# 20
# 1.25

# %%
# WRITE THE PROGRAM READ THE QUDRANT POINT TO DETERMINE THE QUADREANT
x = float(input("enter the number"))
y = float(input("enter the number"))
if x>0 and y>0:
    print("print first quadrant")
elif x<0 and y>0:
  print("print second quadrant")
elif x<0 and y<0:
  print("print third quadrant")
elif x>0 and y<0:
  print("print fourth quadrant")
# Out:
# enter the number9
# enter the number8
# print first quadrant

# %%
# write the program to add two complex numbers
x = int(input("enter the number"))
y = int(input("enter the number"))
z = complex(x,y)
print(z)
# Out:
# enter the number9
# enter the number9
# (9+9j)

# %%
# write the programme to  find roots of the quadratic equation
x = (int(input("cofficient of the quadratic expression")))
b = (int(input("cofficient of  the linear expression")))
c = (int(input("coffficient of the constant expression")))
s = b**2 + 4*x*c
import math
d = -b +- (math.sqrt(s))
print(d)
t = d/(2*x)
print(t)
# Out:
# cofficient of the quadratic expression5
# cofficient of  the linear expression6
# coffficient of the constant expression3
# -15.797958971132712
# -1.579795897113271

# %%
# write the programme to print the day according to day number
day = int(input("enter the number"))
if day == 1:
  print("monday")
elif day == 2:
  print("tuesday")
elif day == 3:
  print("wednesday")
elif day == 4:
  print("thursday")
elif day == 5:
  print("friday")
elif day == 6:
  print("saturday")
elif day == 7:
  print("sunday")
else:
  print("invalid day")
# Out:
# enter the number5
# friday

# %%
letter = input("Enter the first letter: ").upper()
if letter == "R":
    print("Red")
elif letter == "G":
    print("Green")
elif letter == "B":
    print("Blue")
elif letter == "Y":
    print("Yellow")
elif letter == "O":
    print("Orange")
elif letter == "V":
    print("Violet")
else:
    print("Invalid color")
# Out:
# Enter the first letter: o
# Orange
