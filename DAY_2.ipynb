# %% [markdown]
# <a href="https://colab.research.google.com/github/Ratnesh899/python-codes/blob/main/DAY_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello","\n")
print("world")
# Out:
# Hello
#
# world

# %%
print("Hello", end ="\n")
print("world")
# Out:
# Hello
# world

# %%
print("Apple" , "Banana" , "cherry" , sep=",")
print("NIET" , "GREATER" , "NOIDA" , sep="-")
# Out:
# Apple,Banana,cherry
# NIET-GREATER-NOIDA

# %%
#CONCATENATION#
name = "Mishra"
print("Ratnes" " " + name)

#example 2 #
a = input("name")
b = input("age")
print(a + "is" +b + "years old")
# Out:
# Ratnes Mishra
# nameRatnesh
# age19
# Ratneshis19years old

# %%
# Taking user input for two numbers
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))
temp = a
a = b
b = temp
print("After swapping:")
print("First number:", a)
print("Second number:", b)
# Out:
# Enter the first number: 10
# Enter the second number: 5
# After swapping:
# First number: 5
# Second number: 10

# %%
a = 2
power = 2*3
print(power)
# Out:
# 6

# %%
#variables a to z , A to Z
#start with

# %%
#squence data type
my_list = [1,2,3] #list
my_tuple = (1,2,3) #tuple
#mapping data type
details = {"name": "Alice" , "age": 25} #dict

# %%
# type() of user
a = 1
b = 5.7
c = 6
print(type(a)  , type(b)  , type(c))
# Out:
# <class 'int'> <class 'float'> <class 'int'>

# %%
# explicit conversion
x = int(1)
y = int(2.8)
print(x)
print(y)

#example 2 #
x = "10"
y = int(x)+5
print(y)
# Out:
# 1
# 2
# 15

# %%
#implicit
a = (input("enter the number"))
b = (input("enter the number"))
c = a+b
print(c)
print(type(c))
# Out:
# enter the number8
# enter the number9
# 89
# <class 'str'>

# %%
#logical operator (and , or , not)
x = 100
print( x > 29 and x < 50)
print(x > 29 or x < 40)
print(not(12<5) or 10>5)
# Out:
# False
# True
# True

# %%
#bitwise operator
x = 5
y = 3
print( x & y) #and
print(x | y) #or
print(x ^ y) #xor
# shift operator
print(x >> 2) # left shift
print(x << 2) # right shift
# Out:
# 1
# 7
# 6
# 1
# 20

# %%
#Assignment operator
a = float(input("Enter the first number: "))
b = float(input("Enter the second number: "))
a += b
print(a)
a -= b
a *= b
print(a)
# Out:
# Enter the first number: 5
# Enter the second number: 9
# 14.0
# 45.0

# %%
x =102
y = 45
print( x ^ y)
# Out:
# 75

# %%
#member ship operator (in , not in)
x = [1, "A" , 3 , 4 , 5]
print("A" in x)
print("b" not in x)
print( 2 in x)
# Out:
# True
# True
# False

# %%
#Identity operator(is , is not)
x = [1,2 , 2.5, 5, 3]
y = [1,2, 2.5 ,5 ,3]
x = c
print(x is c)
print(x is not y)
print(x is not c)
print(x is y)
# Out:
# True
# True
# False
# False

# %%
# 4. Area of Rhombus
d1 = float(input("Enter first diagonal: "))
d2 = float(input("Enter second diagonal: "))
area = (d1 * d2) / 2
print("Area of Rhombus:", area)

# 5. Area of Parallelogram
base = float(input("Enter base: "))
height = float(input("Enter height: "))
area = base * height
print("Area of Parallelogram:", area)

# 6. Cube Calculations
side = float(input("Enter side length: "))
volume = side ** 3
surface_area = 6 * side ** 2
print("Volume:", volume)
print("Surface Area:", surface_area)

# 7. Cuboid Calculations
length = float(input("Enter length: "))
width = float(input("Enter width: "))
height = float(input("Enter height: "))
volume = length * width * height
surface_area = 2 * (length*width + width*height + height*length)
print("Volume:", volume)
print("Surface Area:", surface_area)

# 8. Cylinder Calculations
radius = float(input("Enter radius: "))
height = float(input("Enter height: "))
pi = 3.14159
volume = pi * radius**2 * height
surface_area = 2 * pi * radius * (radius + height)
print("Volume:", volume)
print("Surface Area:", surface_area)

# 9. Cone Calculations
radius = float(input("Enter radius: "))
height = float(input("Enter height: "))
pi = 3.14159
slant_height = (radius**2 + height**2)**0.5
volume = (1/3) * pi * radius**2 * height
surface_area = pi * radius * (radius + slant_height)
print("Volume:", volume)
print("Surface Area:", surface_area)

# 10. Sphere Calculations
radius = float(input("Enter radius: "))
pi = 3.14159
volume = (4/3) * pi * radius**3
surface_area = 4 * pi * radius**2
print("Volume:", volume)
print("Surface Area:", surface_area)

# 11. Perimeter Calculations
print("Choose shape: 1-Circle, 2-Rectangle, 3-Triangle")
choice = input("Enter choice (1-3): ")
pi = 3.14159

if choice == '1':
    radius = float(input("Enter radius: "))
    perimeter = 2 * pi * radius
    print("Circle Perimeter:", perimeter)
elif choice == '2':
    length = float(input("Enter length: "))
    width = float(input("Enter width: "))
    perimeter = 2 * (length + width)
    print("Rectangle Perimeter:", perimeter)
elif choice == '3':
    s1 = float(input("Enter first side: "))
    s2 = float(input("Enter second side: "))
    s3 = float(input("Enter third side: "))
    perimeter = s1 + s2 + s3
    print("Triangle Perimeter:", perimeter)

# 12. Simple Interest
principal = float(input("Enter principal amount: "))
rate = float(input("Enter rate: "))
time = float(input("Enter time (years): "))
interest = (principal * rate * time) / 100
print("Simple Interest:", interest)

# 13. Fahrenheit to Celsius
fahrenheit = float(input("Enter Fahrenheit temperature: "))
celsius = (fahrenheit - 32) * 5/9
print("Temperature in Celsius:", celsius)

# 14. Swap with temp variable
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
print("Before swap: a =", a, "b =", b)
temp = a
a = b
b = temp
print("After swap: a =", a, "b =", b)

# 15. Swap without temp variable
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
print("Before swap: a =", a, "b =", b)
a = a + b
# 4. Area of Rhombus
d1 = float(input("Enter first diagonal: "))
d2 = float(input("Enter second diagonal: "))
area = (d1 * d2) / 2
print("Area of Rhombus:", area)

# 5. Area of Parallelogram
base = float(input("Enter base: "))
height = float(input("Enter height: "))
area = base * height
print("Area of Parallelogram:", area)

# 6. Cube Calculations
side = float(input("Enter side length: "))
volume = side ** 3
surface_area = 6 * side ** 2
print("Volume:", volume)
print("Surface Area:", surface_area)

# 7. Cuboid Calculations
length = float(input("Enter length: "))
width = float(input("Enter width: "))
height = float(input("Enter height: "))
volume = length * width * height
surface_area = 2 * (length*width + width*height + height*length)
print("Volume:", volume)
print("Surface Area:", surface_area)

# 8. Cylinder Calculations
radius = float(input("Enter radius: "))
height = float(input("Enter height: "))
pi = 3.14159
volume = pi * radius**2 * height
surface_area = 2 * pi * radius * (radius + height)
print("Volume:", volume)
print("Surface Area:", surface_area)

# 9. Cone Calculations
radius = float(input("Enter radius: "))
height = float(input("Enter height: "))
pi = 3.14159
slant_height = (radius**2 + height**2)**0.5
volume = (1/3) * pi * radius**2 * height
surface_area = pi * radius * (radius + slant_height)
print("Volume:", volume)
print("Surface Area:", surface_area)

# 10. Sphere Calculations
radius = float(input("Enter radius: "))
pi = 3.14159
volume = (4/3) * pi * radius**3
surface_area = 4 * pi * radius**2
print("Volume:", volume)
print("Surface Area:", surface_area)

# 11. Perimeter Calculations
print("Choose shape: 1-Circle, 2-Rectangle, 3-Triangle")
choice = input("Enter choice (1-3): ")
pi = 3.14159

if choice == '1':
    radius = float(input("Enter radius: "))
    perimeter = 2 * pi * radius
    print("Circle Perimeter:", perimeter)
elif choice == '2':
    length = float(input("Enter length: "))
    width = float(input("Enter width: "))
    perimeter = 2 * (length + width)
    print("Rectangle Perimeter:", perimeter)
elif choice == '3':
    s1 = float(input("Enter first side: "))
    s2 = float(input("Enter second side: "))
    s3 = float(input("Enter third side: "))
    perimeter = s1 + s2 + s3
    print("Triangle Perimeter:", perimeter)

# 12. Simple Interest
principal = float(input("Enter principal amount: "))
rate = float(input("Enter rate: "))
time = float(input("Enter time (years): "))
interest = (principal * rate * time) / 100
print("Simple Interest:", interest)

# 13. Fahrenheit to Celsius
fahrenheit = float(input("Enter Fahrenheit temperature: "))
celsius = (fahrenheit - 32) * 5/9
print("Temperature in Celsius:", celsius)

# 14. Swap with temp variable
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
print("Before swap: a =", a, "b =", b)
temp = a
a = b
b = temp
print("After swap: a =", a, "b =", b)

# 15. Swap without temp variable
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
print("Before swap: a =", a, "b =", b)
a = a + b
b = a - b
a = a - b
print("After swap: a =", a, "b =", b)
66
# Out:
# Enter first diagonal: 6
# Enter second diagonal: 8
# Area of Rhombus: 24.0
# Enter base: 7
# Enter height: 8
# Area of Parallelogram: 56.0
# Enter side length: 6
# Volume: 216.0
# Surface Area: 216.0
# Enter length: 7
# Enter width: 9
# Enter height: 3
# Volume: 189.0
# Surface Area: 222.0
# Enter radius: 6
# Enter height: 7
# Volume: 791.6806799999999
# Surface Area: 490.0880399999999
# Enter radius: 7
# Enter height: 4
# Volume: 205.25054666666665
# Surface Area: 331.23606823634066
# Enter radius: 3
# Volume: 113.09723999999999
# Surface Area: 113.09724
# Choose shape: 1-Circle, 2-Rectangle, 3-Triangle
# Enter choice (1-3): 5
# Enter principal amount: 3
# Enter rate: 3
# Enter time (years): 6
# Simple Interest: 0.54
# Enter Fahrenheit temperature: 5
# Temperature in Celsius: -15.0
# Enter first number: 7
# Enter second number: 9
# Before swap: a = 7.0 b = 9.0
# After swap: a = 9.0 b = 7.0
# Enter first number: 3
# Enter second number: 2
# Before swap: a = 3.0 b = 2.0
# ...
